# %%
import pandas as pd
import os

# %%
diretorio = '**' ##adicione seu diretório

# %%
lista_df = []
lista_path = os.listdir(diretorio)

# %%
lista_path[:5]
# Out:
# ['2020-01-01.csv',
#  '2020-01-02.csv',
#  '2020-01-03.csv',
#  '2020-01-04.csv',
#  '2020-01-05.csv']

# %%
lista_df = []
for arquivo in lista_path:
    local_arquivo = os.path.join(diretorio, arquivo)
    df = pd.read_csv(local_arquivo, sep = '|', encoding = 'latin-1')
    lista_df.append(df)
dataframe = pd.concat(lista_df)

# %%
dataframe.head(1365)
# Out:
#     cod_pessoa data_coleta     genero data_nascimento animal_estimacao  \
# 0     10141743  2020-01-01  Masculino      1981-04-25            peixe
# 1     10141860  2020-01-01   Feminino      1966-01-19            peixe
# 2     10142548  2020-01-01  Masculino      1973-08-02        tartaruga
# 3     10142591  2020-01-01  Masculino      1997-03-05             gato
# 4     10142654  2020-01-01   Feminino      1969-08-05        tartaruga
# ..         ...         ...        ...             ...              ...
# 6     10143320  2020-08-26  Masculino      1961-09-17        tartaruga
# 7     10143450  2020-08-26   Feminino      1976-07-23             gato
# 0     10141761  2020-08-27  Masculino      1956-02-22             gato
# 1     10142314  2020-08-27  Masculino      1961-03-07            peixe
# 2     10142507  2020-08-27  Masculino      1980-03-24            peixe
#
#        clima bebida_favorita             hobbies
# 0       frio         Cerveja    Praticar esporte
# ...

# %%
dataframe.reset_index(drop=True, inplace=True)

# %%
dataframe.to_csv('dados_tratados', index=True, sep=';')

# %%
pip install mysqlclient
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\juh_o\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\juh_o\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import MySQLdb
import sqlalchemy

# %%
user = '**' ##digite seu username
password = '**' ##digite seu password
host = 'localhost'
database = '**' ## como chamará sua tabela no sql 

string_conexao = f'mysql://{user}:{password}@{host}/{database}'
string_conexao
# Out:
# 'mysql://**:**@localhost/**'

# %%
engine = sqlalchemy.create_engine(string_conexao)
conn = engine.connect()

# %%
#não pode ter valores duplicados
df_pessoa = dataframe[['cod_pessoa', 'genero', 'data_nascimento']].drop_duplicates()
hobbies = list(dataframe.hobbies.unique())
climas = list(dataframe.clima.unique())
bebidas = list(dataframe.bebida_favorita.unique())
animais_estimacao = list(dataframe.animal_estimacao.unique())

# %%
df_pessoa[:10]
# Out:
#    cod_pessoa     genero data_nascimento
# 0    10141743  Masculino      1981-04-25
# 1    10141860   Feminino      1966-01-19
# 2    10142548  Masculino      1973-08-02
# 3    10142591  Masculino      1997-03-05
# 4    10142654   Feminino      1969-08-05
# 5    10141523   Feminino      1998-09-24
# 6    10141996   Feminino      1973-03-13
# 7    10142089   Feminino      1970-03-23
# 8    10142145  Masculino      1998-08-01
# 9    10142520  Masculino      1994-05-09

# %%
hobbies
# Out:
# ['Praticar esporte',
#  'Assistir TV',
#  'Ler livros',
#  'Aprender algo novo',
#  'Escrever',
#  'Pintar quadros',
#  'Dormir',
#  'Escutar música']

# %%
climas
# Out:
# ['frio', 'quente', 'moderado']

# %%
bebidas
# Out:
# ['Cerveja', 'Café', 'refrigerante', 'Água', 'Vinho', 'Chá']

# %%
animais_estimacao
# Out:
# ['peixe', 'tartaruga', 'gato', 'cachorro']

# %%
for pessoa in df_pessoa.itertuples():
    print(pessoa)
# Out:
# Pandas(Index=0, cod_pessoa=10141743, genero='Masculino', data_nascimento='1981-04-25')
# Pandas(Index=1, cod_pessoa=10141860, genero='Feminino', data_nascimento='1966-01-19')
# Pandas(Index=2, cod_pessoa=10142548, genero='Masculino', data_nascimento='1973-08-02')
# Pandas(Index=3, cod_pessoa=10142591, genero='Masculino', data_nascimento='1997-03-05')
# Pandas(Index=4, cod_pessoa=10142654, genero='Feminino', data_nascimento='1969-08-05')
# Pandas(Index=5, cod_pessoa=10141523, genero='Feminino', data_nascimento='1998-09-24')
# Pandas(Index=6, cod_pessoa=10141996, genero='Feminino', data_nascimento='1973-03-13')
# Pandas(Index=7, cod_pessoa=10142089, genero='Feminino', data_nascimento='1970-03-23')
# Pandas(Index=8, cod_pessoa=10142145, genero='Masculino', data_nascimento='1998-08-01')
# Pandas(Index=9, cod_pessoa=10142520, genero='Masculino', data_nascimento='1994-05-09')
# Pandas(Index=10, cod_pessoa=10143160, genero='Feminino', data_nascimento='1967-09-18')
# ...

# %%
for pessoa in df_pessoa.itertuples():
    cod_pessoa = pessoa.cod_pessoa
    genero = pessoa.genero
    data_nascimento = str(pessoa.data_nascimento)
    try:
        query = f'''insert into pessoa (cod_pessoa, genero, data_nascimento)
                    values('{cod_pessoa}', '{genero}', '{data_nascimento}')'''
        conn.execute(query)
        print(f'Registro inserido com sucesso: {cod_pessoa}')

    except Exception as e:
        print(f'Não foi possível inserir o registro {cod_pessoa}. O erro encontrado foi: {e}')
# Out:
# Registro inserido com sucesso: 10141743
# Registro inserido com sucesso: 10141860
# Registro inserido com sucesso: 10142548
# Registro inserido com sucesso: 10142591
# Registro inserido com sucesso: 10142654
# Registro inserido com sucesso: 10141523
# Registro inserido com sucesso: 10141996
# Registro inserido com sucesso: 10142089
# Registro inserido com sucesso: 10142145
# Registro inserido com sucesso: 10142520
# Registro inserido com sucesso: 10143160
# Registro inserido com sucesso: 10141712
# Registro inserido com sucesso: 10141987
# Registro inserido com sucesso: 10142093
# Registro inserido com sucesso: 10142325
# Registro inserido com sucesso: 10142552
# Registro inserido com sucesso: 10142598
# Registro inserido com sucesso: 10143013
# Registro inserido com sucesso: 10141570
# Registro inserido com sucesso: 10141851
# Registro inserido com sucesso: 10141938
# Registro inserido com sucesso: 10142733
# Registro inserido com sucesso: 10142851
# ...

# %%
for hobbie in hobbies:
    try:
        query = f'''insert into hobbie (hobbie)
                    values('{hobbie}')'''
        conn.execute(query)
        print(f'Registro inserido com sucesso: {hobbie}')

    except Exception as e:
        print(f'Não foi possível inserir o registro {hobbie}. O erro encontrado foi: {e}')
# Out:
# Registro inserido com sucesso: Praticar esporte
# Registro inserido com sucesso: Assistir TV
# Registro inserido com sucesso: Ler livros
# Registro inserido com sucesso: Aprender algo novo
# Registro inserido com sucesso: Escrever
# Registro inserido com sucesso: Pintar quadros
# Registro inserido com sucesso: Dormir
# Registro inserido com sucesso: Escutar música

# %%
for clima in climas:
    try:
        query = f'''insert into clima (clima)
                    values('{clima}')'''
        conn.execute(query)
        print(f'Registro inserido com sucesso: {clima}')

    except Exception as e:
        print(f'Não foi possível inserir o registro {clima}. O erro encontrado foi: {e}')
# Out:
# Registro inserido com sucesso: frio
# Registro inserido com sucesso: quente
# Registro inserido com sucesso: moderado

# %%
for bebida in bebidas:
    try:
        query = f'''insert into bebida (bebida)
                    values('{bebida}')'''
        conn.execute(query)
        print(f'Registro inserido com sucesso: {bebida}')

    except Exception as e:
        print(f'Não foi possível inserir o registro {bebida}. O erro encontrado foi: {e}')
# Out:
# Registro inserido com sucesso: Cerveja
# Registro inserido com sucesso: Café
# Registro inserido com sucesso: refrigerante
# Registro inserido com sucesso: Água
# Registro inserido com sucesso: Vinho
# Registro inserido com sucesso: Chá

# %%
for animal_estimacao in animais_estimacao:
    try:
        query = f'''insert into animal_estimacao (animal)
                    values('{animal_estimacao}')'''
        conn.execute(query)
        print(f'Registro inserido com sucesso: {animal_estimacao}')

    except Exception as e:
        print(f'Não foi possível inserir o registro {animal_estimacao}. O erro encontrado foi: {e}')
# Out:
# Registro inserido com sucesso: peixe
# Registro inserido com sucesso: tartaruga
# Registro inserido com sucesso: gato
# Registro inserido com sucesso: cachorro

# %%
df_hobbie = pd.read_sql('hobbie', con=conn)
df_clima = pd.read_sql('clima', con=conn)
df_bebida = pd.read_sql('bebida', con=conn)
df_animal_estimacao = pd.read_sql('animal_estimacao', con=conn)

# %%
dict_hobbie = df_hobbie.set_index(df_hobbie.hobbie)['cod_hobbie'].to_dict()
dict_hobbie
# Out:
# {'Aprender algo novo': 4,
#  'Assistir TV': 2,
#  'Dormir': 7,
#  'Escrever': 5,
#  'Escutar música': 8,
#  'Ler livros': 3,
#  'Pintar quadros': 6,
#  'Praticar esporte': 1}

# %%
dict_clima = df_clima.set_index(df_clima.clima)['cod_clima'].to_dict()
dict_clima
# Out:
# {'frio': 1, 'moderado': 3, 'quente': 2}

# %%
dict_bebida = df_bebida.set_index(df_bebida.bebida)['cod_bebida'].to_dict()
dict_bebida
# Out:
# {'Água': 4, 'Café': 2, 'Cerveja': 1, 'Chá': 6, 'refrigerante': 3, 'Vinho': 5}

# %%
dict_animal_estimacao = df_animal_estimacao.set_index(df_animal_estimacao.animal)['cod_animal_estimacao'].to_dict()
dict_animal_estimacao
# Out:
# {'cachorro': 4, 'gato': 3, 'peixe': 1, 'tartaruga': 2}

# %%
dataset = dataframe.copy()
dataset.head(1)
# Out:
#    cod_pessoa data_coleta     genero data_nascimento animal_estimacao clima  \
# 0    10141743  2020-01-01  Masculino      1981-04-25            peixe  frio
#
#   bebida_favorita           hobbies
# 0         Cerveja  Praticar esporte

# %%
dataset.hobbies = dataset.hobbies.map(dict_hobbie) 
dataset.bebida_favorita = dataset.bebida_favorita.map(dict_bebida)
dataset.clima = dataset.clima.map(dict_clima) 
dataset.animal_estimacao = dataset.animal_estimacao.map(dict_animal_estimacao)
dataset.head(1)
# Out:
#    cod_pessoa data_coleta     genero data_nascimento  animal_estimacao  clima  \
# 0    10141743  2020-01-01  Masculino      1981-04-25                 1      1
#
#    bebida_favorita  hobbies
# 0                1        1

# %%
dataset = dataset.rename(columns={'animal_estimacao':'cod_animal_estimacao','clima':'cod_clima','bebida_favorita':'cod_bebida','hobbies':'cod_hobbie'})
dataset.head(1)
# Out:
#    cod_pessoa data_coleta     genero data_nascimento  cod_animal_estimacao  \
# 0    10141743  2020-01-01  Masculino      1981-04-25                     1
#
#    cod_clima  cod_bebida  cod_hobbie
# 0          1           1           1

# %%
df_pesquisa = dataset[['cod_pessoa', 'data_coleta', 'cod_animal_estimacao', 'cod_clima', 'cod_bebida', 'cod_hobbie']]
df_pesquisa
# Out:
#       cod_pessoa data_coleta  cod_animal_estimacao  cod_clima  cod_bebida  \
# 0       10141743  2020-01-01                     1          1           1
# 1       10141860  2020-01-01                     1          2           2
# 2       10142548  2020-01-01                     2          1           2
# 3       10142591  2020-01-01                     3          3           1
# 4       10142654  2020-01-01                     2          3           2
# ...          ...         ...                   ...        ...         ...
# 2122    10142475  2020-12-31                     1          2           2
# 2123    10142522  2020-12-31                     1          3           1
# 2124    10142881  2020-12-31                     3          1           3
# 2125    10143184  2020-12-31                     2          2           3
# 2126    10143307  2020-12-31                     2          3           3
#
#       cod_hobbie
# 0              1
# 1              2
# 2              3
# ...

# %%
 for pesquisa in df_pesquisa.itertuples():
    cod_pessoa = pesquisa.cod_pessoa
    cod_animal_estimacao = pesquisa.cod_animal_estimacao
    cod_clima = pesquisa.cod_clima
    cod_bebida = pesquisa.cod_bebida
    cod_hobbie = pesquisa.cod_hobbie
    try:
        query = f'''insert into pesquisa (cod_pessoa, cod_animal_estimacao, cod_clima, cod_bebida, cod_hobbie)
                    values('{cod_pessoa}, '{cod_animal_estimacao}', '{cod_clima}', '{cod_bebida}', {cod_hobbie})'''
        conn.execute(query)
        print(f'Registro inserido com sucesso: {cod_pessoa}')

    except Exception as e:
       print(f'Não foi possível inserir o registro {cod_pessoa}. O erro encontrado foi: {e}')/

# %%
df_pesquisa.to_sql('stg_pesquisa', con=conn, schema='tp2')
# Out:
# 2127
